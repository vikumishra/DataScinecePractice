# %% [markdown]
# ### 1)

# %% [markdown]
# * Flask is web development framework developed in python

# %% [markdown]
# * Adavantages are =>
# * Flask provides a development server and a debugger.
# * It provides integrated support for unit testing.
# * It is easy to use

# %% [markdown]
# ### 2)

# %% [markdown]
# ![Screenshot 2023-02-19 at 11.02.39 PM.png](attachment:4eb8f5b9-dabb-4b69-9ecb-0e925c3edda8.png)

# %% [markdown]
# ### 3)

# %% [markdown]
# App Routing means mapping the URLs to a specific function that will handle the logic for that URL.
# We do app routing by proving path inside app.route() decorator

# %% [markdown]
# ### 4)

# %% [markdown]
# ![Screenshot 2023-02-20 at 10.09.07 AM.png](attachment:ca7cf571-6ca3-480a-beae-a6c275ca7ca0.png)

# %% [markdown]
# ![Screenshot 2023-02-20 at 10.18.50 AM.png](attachment:02a8b41a-33b2-4d28-9a83-418dcc1953d8.png)

# %% [markdown]
# ### 5)

# %% [markdown]
# url_for() function is used for url binding. Below code will demonstrate the same.

# %%
# from flask import Flask, redirect, url_for
# app = Flask(__name__)

# @app.route('/admin')
# def hello_admin():
#    return 'Hello Admin'

# @app.route('/guest/<guest>')
# def hello_guest(guest):
#    return 'Hello %s as Guest' % guest

# @app.route('/user/<name>')
# def hello_user(name):
#    if name =='admin':
#       return redirect(url_for('hello_admin'))
#    else:
#       return redirect(url_for('hello_guest',guest = name))

# if __name__ == '__main__':
#    app.run(debug = True)

# %% [markdown]
# In above code if user enters admin he will be redirected to admin page and if he enters guest he will be redirected to guest page
