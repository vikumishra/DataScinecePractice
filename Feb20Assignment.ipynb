# %% [markdown]
# ### 1)

# %% [markdown]
# * GET => This method is used to get data from link.Its used to send data from client to server
# * POST => This method is used to get data from html form.

# %% [markdown]
# ### 2)

# %% [markdown]
# Request is an object that contains all the data sent from the Client to Server.
# This data can be recovered using the GET/POST Methods.

# %% [markdown]
# ### 3)

# %% [markdown]
# Redirect is used to send user to a new or different link along with status code incase the link he is trying
# to reach fails.When called, it returns a response object and redirects the user to another target location with specified status code.

# %% [markdown]
# ### 4)

# %% [markdown]
# * Templates consist of html/web pages . These are the files that consist of static as well as dynamic data
# * render_template() => This function is used to redirect a user to a particular web page incase the satisfying
#                        route on that function is hit.

# %% [markdown]
# ### 5)![Screenshot 2023-02-21 at 12.10.05 AM.png](attachment:a771faf2-9ed0-4922-a22e-cc23be35bf97.png)
