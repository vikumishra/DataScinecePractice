# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1)

# %% [markdown]
# * Matlplot is a python library that is used for visualization.
# * Plots that can be generated using it are :- 1)Scatter 2)Line 3)Bar 4)Histogram 5) Piechart 6)Donut

# %% [markdown]
# ### 2)

# %% [markdown]
# * Scatter plot plots data between x and y axis as dot

# %%
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.scatter(x,y)
plt.title("Scatter Plot")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.show()

# %% [markdown]
# ### 3)

# %% [markdown]
# * Subplot function is used to draw multive plots in one figure.

# %%
#line1
x1= np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])

plt.subplot(2,2,1)
plt.plot(x1,y1)

#line 2
x2 = np.array([0, 1, 2, 3, 4, 5]) 
y2 = np.array([50, 20, 40, 20, 60, 70])

plt.subplot(2,2,2)
plt.plot(x2,y2)



#line 3
x3 = np.array([0, 1, 2, 3, 4, 5]) 
y3 = np.array([10, 20, 30, 40, 50, 60])

plt.subplot(2,2,3)
plt.plot(x3,y3)



#line 4
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(2,2,4)
plt.plot(x4,y4)

# %% [markdown]
# ### 4)

# %% [markdown]
# * Bar plot is a bar graph which is used to show the visualised data between categorical and numerical values

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
plt.xlabel("Company Name")
plt.ylabel("Total Profit")
plt.title("Company And Profit Earned")
plt.show()

# %% [markdown]
# ### 5)

# %% [markdown]
# * A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like     minimum, first quartile, median, third quartile and maximum. In the box plot, a box is created from the first quartile to the   third quartile, a vertical line is also there which goes through the box at the median. Here x-axis denotes the data to be     plotted while the y-axis shows the frequency distribution.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
plt.boxplot(box1)
plt.title("Box 1")
# Out:
# Text(0.5, 1.0, 'Box 1')

# %%
plt.boxplot(box2)
plt.title("Box2")
plt.show()
